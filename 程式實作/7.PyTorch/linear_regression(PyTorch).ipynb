# %%
import torch
from torch.autograd import Variable

# %%
x_data = Variable(torch.Tensor([[1.0], [2.0], [3.0]]))
y_data = Variable(torch.Tensor([[2.0], [4.0], [6.0]]))

# %%
class Model(torch.nn.Module):

    def __init__(self):
        """
        In the constructor we instantiate two nn.Linear module
        """
        super(Model, self).__init__()#super(Model, self)或是super()改寫它
        self.linear = torch.nn.Linear(1, 1)  # One in and one out (1, 1) i in iout

    def forward(self, x):
        """
        In the forward function we accept a Variable of input data and we must return
        a Variable of output data. We can use Modules defined in the constructor as
        well as arbitrary operators on Variables.
        """
        y_pred = self.linear(x)
        return y_pred

# our model
model = Model()


# Construct our loss function and an Optimizer. The call to model.parameters()
# in the SGD constructor will contain the learnable parameters of the two
# nn.Linear modules which are members of the model.
criterion = torch.nn.MSELoss(size_average=False) #最小損失參數
optimizer = torch.optim.SGD(model.parameters(), lr=0.01) #優化參數

# Training loop
for epoch in range(500):
        # Forward pass: Compute predicted y by passing x to the model
    y_pred = model(x_data)

    # Compute and print loss
    loss = criterion(y_pred, y_data)#(y-y^)平方
    print(epoch, loss.data)

    # Zero gradients, perform a backward pass, and update the weights.
    #所有人的gradients都歸0
    optimizer.zero_grad()
    loss.backward()#有用到就.backward()沿著線找gradients
    optimizer.step()#走一步(主要修正w和b的值)


# After training
hour_var = Variable(torch.Tensor([[4.0]]))
y_pred = model(hour_var)
print("predict (after training)",  4, model(hour_var).data[0][0])
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# 0 tensor(129.7133)
# 1 tensor(57.9803)
# 2 tensor(26.0434)
# 3 tensor(11.8227)
# 4 tensor(5.4887)
# 5 tensor(2.6658)
# 6 tensor(1.4059)
# 7 tensor(0.8419)
# 8 tensor(0.5877)
# 9 tensor(0.4715)
# 10 tensor(0.4167)
# 11 tensor(0.3894)
# 12 tensor(0.3743)
# 13 tensor(0.3647)
# 14 tensor(0.3576)
# 15 tensor(0.3516)
# 16 tensor(0.3461)
# 17 tensor(0.3410)
# 18 tensor(0.3360)
# 19 tensor(0.3312)
# 20 tensor(0.3264)
# 21 tensor(0.3217)
# 22 tensor(0.3171)
# 23 tensor(0.3125)
# 24 tensor(0.3080)
# 25 tensor(0.3036)
# 26 tensor(0.2992)
# 27 tensor(0.2949)
# 28 tensor(0.2907)
# 29 tensor(0.2865)
# 30 tensor(0.2824)
# 31 tensor(0.2783)
# 32 tensor(0.2743)
# 33 tensor(0.2704)
# 34 tensor(0.2665)
# 35 tensor(0.2627)
# 36 tensor(0.2589)
# 37 tensor(0.2552)
# 38 tensor(0.2515)
# 39 tensor(0.2479)
# ...
